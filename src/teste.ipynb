# %% [markdown]
# # Testando criação da animação

# %% [markdown]
# ## Classe animação

# %%
from lib.HittableList import HittableList
from lib.objects.Model import Model
from lib.objects.Sphere import Sphere
from lib.materials.Metal import Metal
from lib.materials.Lambertian import Lambertian
from lib.vec.Vec3 import Vec3, Point3, Color
from lib.Camera import Camera

class Animation:

    def __init__(self, image_width: int, samples_per_pixel: int, max_depth: int):
        self.image_width = image_width
        self.samples_per_pixel = samples_per_pixel
        self.max_depth = max_depth
        
        # Configurações da animação:
        self.FRAMES_PER_SECOND = 24
        self.ANIMATION_DURATION = 5  # Em segundos
        self.SPHERES_ROTATION_SPEED = 2 / 5  # A cada 5 segundos, as esferas dão 2 voltas
        self.CAMERA_ROTATION_SPEED = 1 / 5  # A cada 5 segundos, a câmera se move 1 

        # Construindo a cena inicial:
        self.cube = Model("../objs/Cube.obj", Metal(Color([0.7, 0.7, 0.7]), 0.0))

        self.first_sphere = Sphere(
            Point3([-2, 0, 0]),
            0.5,
            Lambertian(Color([0.9, 0.3, 0.3]))
        )
        self.second_sphere = Sphere(
            Point3([2, 0, 0]),
            0.5,
            Lambertian(Color([0.3, 0.3, 0.9]))
        )
        self.floor = Sphere(
            Point3([0, -100.5, -1]), 
            100,
            Lambertian(Color([0.5, 1, 0.5]))
        )

        self.camera_initial_position = Point3([0, 2, 5])

        self.camera = Camera(
            image_width=self.image_width,
            samples_per_pixel=self.samples_per_pixel,
            max_depth=self.max_depth,
            vfov=40,
            lookfrom=self.camera_initial_position,
            lookat=Point3([0, 0, 0]),
            vup=Vec3([0, 1, 0])
        )
    
    def generate_frame(self, frame_number: int, save_path: str):
        # Calculando o tempo atual da animação:
        current_time = frame_number / self.FRAMES_PER_SECOND

        # Atualizando posição da camera
        self.camera.lookfrom = self.camera_initial_position.rotate(
            'y', current_time * self.CAMERA_ROTATION_SPEED * 360
        )

        # Atualizando posição das esferas
        new_first_sphere = self.first_sphere.rotate(
            'y', current_time * self.SPHERES_ROTATION_SPEED * 360
        )

        new_second_sphere = self.second_sphere.rotate(
            'y', current_time * self.SPHERES_ROTATION_SPEED * 360
        )

        # Criando a cena
        world = HittableList()
        world.add(self.cube)
        world.add(new_first_sphere)
        world.add(new_second_sphere)
        world.add(self.floor)

        # Renderizando a imagem
        self.camera.render(world, save_path)

# %% [markdown]
# ## Testando

# %%
anim_path = '../animation_frames/notebook_tests'
anim = Animation(100, 1, 10)

# %%
for frame_number in range(anim.FRAMES_PER_SECOND * anim.ANIMATION_DURATION):
    print(f'Generating frame {frame_number}...')
    anim.generate_frame(frame_number, f'{anim_path}/frame_{frame_number}.png')
# Out:
# Generating frame 0...
#   0%|          | 0/56 [00:00<?, ?it/s]
# 100%|██████████| 56/56 [00:11<00:00,  4.91it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame
/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 86...
# 100%|██████████| 56/56 [00:11<00:00,  4.87it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 87...
# 100%|██████████| 56/56 [00:10<00:00,  5.17it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 88...
# 100%|██████████| 56/56 [00:10<00:00,  5.18it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 89...
# 100%|██████████| 56/56 [00:10<00:00,  5.48it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 90...
# 100%|██████████| 56/56 [00:11<00:00,  5.02it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 91...
# 100%|██████████| 56/56 [00:10<00:00,  5.59it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 92...
# 100%|██████████| 56/56 [00:10<00:00,  5.16it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 93...
# 100%|██████████| 56/56 [00:13<00:00,  4.17it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 94...
# 100%|██████████| 56/56 [00:09<00:00,  5.67it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 95...
# 100%|██████████| 56/56 [00:09<00:00,  5.73it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 96...
# 100%|██████████| 56/56 [00:11<00:00,  4.69it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 97...
# 100%|██████████| 56/56 [00:11<00:00,  4.90it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 98...
# 100%|██████████| 56/56 [00:10<00:00,  5.53it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 99...
# 100%|██████████| 56/56 [00:11<00:00,  5.01it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 100...
# 100%|██████████| 56/56 [00:10<00:00,  5.31it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 101...
# 100%|██████████| 56/56 [00:10<00:00,  5.19it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 102...
# 100%|██████████| 56/56 [00:10<00:00,  5.36it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 103...
# 100%|██████████| 56/56 [00:11<00:00,  4.98it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 104...
# 100%|██████████| 56/56 [00:10<00:00,  5.10it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 105...
# 100%|██████████| 56/56 [00:10<00:00,  5.24it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 106...
# 100%|██████████| 56/56 [00:10<00:00,  5.31it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 107...
# 100%|██████████| 56/56 [00:10<00:00,  5.25it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 108...
# 100%|██████████| 56/56 [00:10<00:00,  5.26it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 109...
# 100%|██████████| 56/56 [00:10<00:00,  5.25it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 110...
# 100%|██████████| 56/56 [00:10<00:00,  5.18it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 111...
# 100%|██████████| 56/56 [00:10<00:00,  5.35it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 112...
# 100%|██████████| 56/56 [00:10<00:00,  5.31it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 113...
# 100%|██████████| 56/56 [00:10<00:00,  5.41it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 114...
# 100%|██████████| 56/56 [00:10<00:00,  5.52it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 115...
# 100%|██████████| 56/56 [00:10<00:00,  5.45it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 116...
# 100%|██████████| 56/56 [00:10<00:00,  5.09it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 117...
# 100%|██████████| 56/56 [00:11<00:00,  4.85it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 118...
# 100%|██████████| 56/56 [00:10<00:00,  5.16it/s]
# <PIL.Image.Image image mode=RGB size=100x56>
# Generating frame 119...
# 100%|██████████| 56/56 [00:09<00:00,  5.62it/s]
# <PIL.Image.Image image mode=RGB size=100x56>

# %%
# Código para salvar animação em vídeo
# Código adaptado de: https://stackoverflow.com/a/44948030

import cv2
import os

image_folder = '../animation_frames/notebook_tests'
video_name = '../animations/notebook_test.avi'

images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
images.sort(key= lambda file: int(file.split('_')[1].split('.')[0]))  # Ordenando as imagens pelo número do frame (por padrão, a ordenação por string não dá certo)
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 24, (anim.camera.image_width, anim.camera.image_height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()
